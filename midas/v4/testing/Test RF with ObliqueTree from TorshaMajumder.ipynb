# %% [markdown]
# # **Test RF with ObliqueTree from TorshaMajumder**

# %% [markdown]
# https://github.com/TorshaMajumder/Ensembles_of_Oblique_Decision_Trees
#
# https://github.com/valevalerio/Ensemble_Of_Oblique_Decision_Trees

# %%
FOLDERS= ['/content/drive/MyDrive/',
          '/content/drive/MyDrive/midas',
          '/content/drive/MyDrive/Testes e Experimentos/Testes/lib.external',
          '/content/drive/MyDrive/Testes e Experimentos/Testes/lib.external/TorshaMajumder',
          '/content/drive/MyDrive/Testes e Experimentos/Testes/lib.external/TorshaMajumder/Decision_trees']
import sys
for f in FOLDERS:
  sys.path.append(f)

import pandas as pd

import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.tree import DecisionTreeClassifier

from midas.v4.ensemble import RFClassifier

# %%
df_stream = pd.read_csv('https://github.com/scikit-multiflow/streaming-datasets/raw/master/agr_a.csv',
                        engine='c', low_memory=True, memory_map=True)

X = df_stream[df_stream.columns[:-1]]
y = df_stream['class']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.70, random_state=100)

# %% [markdown]
# ## Testa as árvores obliquas individualmente

# %%
from TorshaMajumder.Decision_trees.CO2 import ContinuouslyOptimizedObliqueTree, CO2Classifier
from TorshaMajumder.Decision_trees.segmentor import Twoing, MSE, MeanSegmentor
from TorshaMajumder.Decision_trees.split_criteria import gini, twoing

# Continuous Optimization of Oblique Splits (CO2) by [Norouzi et al.]
# CO2Classifier(MSE(),MeanSegmentor(), max_depth=50, min_samples_split=2, nu=4.0, tau=10, tol=1e-3, eta=0.01)
co2t = ContinuouslyOptimizedObliqueTree(impurity=MSE(),
                                        segmentor=MeanSegmentor(), 
                                        max_depth=5,
                                        min_samples_split=2,
                                        nu=1.0,
                                        tau=10,
                                        tol=1e-3,
                                        eta=0.1)

co2t.fit(X_train.to_numpy(copy=True), y_train.to_numpy(copy=True))

y_pred = co2t.predict(X_test.to_numpy(copy=True))

print('Acc: ', accuracy_score(y_test, y_pred))
# Out:
# Acc:  0.5279442857142858

# %%
from TorshaMajumder.Decision_trees.HouseHolder_CART import HouseHolderCART, HHCartClassifier
from TorshaMajumder.Decision_trees.segmentor import Twoing, MSE, MeanSegmentor
from TorshaMajumder.Decision_trees.split_criteria import gini, twoing

# HouseHolder CART-A by [Wickramarachchi et al.]
# HHCartClassifier(MSE(),MeanSegmentor(), max_depth=50, min_samples_split=2, alpha=None))
hhc = HouseHolderCART(impurity=MSE(),
                      segmentor=MeanSegmentor(),
                      max_depth=5,
                      min_samples_split=2,
                      method='eig',
                      tau=10,
                      alpha=None)
hhc.fit(X_train.to_numpy(copy=True), y_train.to_numpy(copy=True))

y_pred = hhc.predict(X_test.to_numpy(copy=True))

print('Acc: ', accuracy_score(y_test, y_pred))
# Out:
# Acc:  0.6686614285714285

# %%
from TorshaMajumder.Decision_trees.NDT import *
from TorshaMajumder.Decision_trees.segmentor import Twoing, MSE, MeanSegmentor
from TorshaMajumder.Decision_trees.split_criteria import gini, twoing

# Non-Linear Decision Trees by [Ittner et al.]
# 
ndtc = NDTClassifier(criterion="gini",
                     max_depth=5,
                     min_samples_split=2,
                     min_features_split=1)
ndtc.fit(X_train.to_numpy(copy=True), y_train.to_numpy(copy=True))

y_pred = ndtc.predict(X_test.to_numpy(copy=True))

print('Acc: ', accuracy_score(y_test, y_pred))

# %%
from TorshaMajumder.Decision_trees.Oblique_Classifier_1 import *
from TorshaMajumder.Decision_trees.segmentor import Twoing, MSE, MeanSegmentor
from TorshaMajumder.Decision_trees.split_criteria import gini, twoing

# Oblique Classifier 1 (OC1) by [Murthy et al.]
# 
obc1 = ObliqueClassifier1(criterion="gini",
                          max_depth=3,
                          min_samples_split=2,
                          min_features_split=1)
obc1.fit(X_train.to_numpy(copy=True), y_train.to_numpy(copy=True))

y_pred = obc1.predict(X_test.to_numpy(copy=True))

print('Acc: ', accuracy_score(y_test, y_pred))

# %%
from TorshaMajumder.Decision_trees.RandCART import *
from TorshaMajumder.Decision_trees.segmentor import Twoing, MSE, MeanSegmentor
from TorshaMajumder.Decision_trees.split_criteria import gini, twoing

# Randomized CART
# RandCARTClassifier(impurity=MSE(), segmentor=MeanSegmentor(), max_depth=50, min_samples_split=2)
rcc = Rand_CART(impurity=MSE(),
                segmentor=MeanSegmentor(),
                max_depth=5,
                min_samples_split=2,
                compare_with_cart=False)

rcc.fit(X_train.to_numpy(copy=True), y_train.to_numpy(copy=True))

y_pred = rcc.predict(X_test.to_numpy(copy=True))

print('Acc: ', accuracy_score(y_test, y_pred))
# Out:
# Acc:  0.61188

# %%
from TorshaMajumder.Decision_trees.WODT import *
from TorshaMajumder.Decision_trees.segmentor import Twoing, MSE, MeanSegmentor
from TorshaMajumder.Decision_trees.split_criteria import gini, twoing

# Weighted Oblique Decision Trees by [Bin-Bin Yang et al.]
# WeightedObliqueDecisionTreeClassifier(max_depth=50, min_samples_split=2, max_features='all')
wodt = WeightedObliqueDecisionTreeClassifier(max_depth=50,
                                             min_samples_split=2,
                                             max_features='all')

wodt.fit(X_train.to_numpy(copy=True), y_train.to_numpy(copy=True))

y_pred = wodt.predict(X_test.to_numpy(copy=True))

print('Acc: ', accuracy_score(y_test, y_pred))
# Out:
# Acc:  0.6096614285714286

# %% [markdown]
# ##Testa com a implementação do RF

# %%
from TorshaMajumder.Decision_trees.CO2 import ContinuouslyOptimizedObliqueTree, CO2Classifier
from TorshaMajumder.Decision_trees.segmentor import Twoing, MSE, MeanSegmentor
from TorshaMajumder.Decision_trees.split_criteria import gini, twoing

# Continuous Optimization of Oblique Splits (CO2)

cfg_base_estimator = {'impurity':MSE(),
                      'segmentor':MeanSegmentor(),
                      'max_depth':3,
                      'min_samples_split':2,
                      'nu':1.0,
                      'tau':10,
                      'tol':1e-3,
                      'eta':0.1}

rf = RFClassifier(base_estimator=ContinuouslyOptimizedObliqueTree,
                  n_estimators=10,
                  params_estimators=cfg_base_estimator,
                  enable_logger=True)

rf._setup_logger(log_file='/content/drive/MyDrive/Testes e Experimentos/Testes/rf.co2.debuging.log')

rf = rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)

print('Acc with oblique tree', accuracy_score(y_test, y_pred))
# Out:
# INFO:rflog:Tree index [1] build with the feature index [0, 8, 1] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [0] build with the feature index [6, 0, 3] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [2] build with the feature index [4, 8, 6] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [4] build with the feature index [1, 8, 5] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [3] build with the feature index [8, 1, 5] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [6] build with the feature index [8, 7, 1] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [5] build with the feature index [3, 0, 1] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [8] build with the feature index [0, 5, 4] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [9] build with the feature index [2, 8, 4] and data index [230065 250494  37253 ... 274949 143113  23736]

# %%
from TorshaMajumder.Decision_trees.HouseHolder_CART import HouseHolderCART, HHCartClassifier
from TorshaMajumder.Decision_trees.segmentor import Twoing, MSE, MeanSegmentor
from TorshaMajumder.Decision_trees.split_criteria import gini, twoing

# HouseHolder CART-A by [Wickramarachchi et al.]
# 

cfg_base_estimator = {'impurity':MSE(),
                      'segmentor':MeanSegmentor(),
                      'max_depth':3,
                      'min_samples_split':2,
                      'method':'eig',
                      'tau':10,
                      'alpha':None}

rf = RFClassifier(base_estimator=HouseHolderCART,
                  n_estimators=100,
                  params_estimators=cfg_base_estimator,
                  enable_logger=True)

rf._setup_logger(log_file='/content/drive/MyDrive/Testes e Experimentos/Testes/rf.hhc.debuging.log')

rf = rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)

print('Acc with oblique tree', accuracy_score(y_test, y_pred))
# Out:
# INFO:rflog:Tree index [1] build with the feature index [7, 3, 0] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [0] build with the feature index [2, 1, 3] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [3] build with the feature index [0, 1, 6] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [2] build with the feature index [2, 1, 8] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [5] build with the feature index [3, 6, 8] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [4] build with the feature index [1, 3, 2] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [6] build with the feature index [1, 5, 8] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [7] build with the feature index [3, 2, 4] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [8] build with the feature index [3, 5, 1] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [9] build with the feature index [5, 7, 2] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [10] build with the feature index [2, 5, 1] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [11] build with the feature index [2, 7, 1] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [12] build with the feature index [4, 6, 0] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [13] build with the feature index [1, 6, 5] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [14] build with the feature index [6, 7, 3] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [15] build with the feature index [1, 0, 2] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [16] build with the feature index [2, 0, 7] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [17] build with the feature index [0, 4, 2] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [18] build with the feature index [1, 5, 3] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [19] build with the feature index [6, 2, 3] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [20] build with the feature index [7, 5, 6] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [21] build with the feature index [3, 8, 4] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [22] build with the feature index [3, 5, 4] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [23] build with the feature index [8, 4, 3] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [24] build with the feature index [2, 6, 5] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [25] build with the feature index [2, 0, 5] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [26] build with the feature index [5, 3, 6] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [27] build with the feature index [3, 2, 1] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [28] build with the feature index [5, 0, 2] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [29] build with the feature index [5, 8, 7] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [30] build with the feature index [7, 1, 8] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [31] build with the feature index [0, 3, 6] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [32] build with the feature index [1, 4, 2] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [33] build with the feature index [7, 4, 8] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [34] build with the feature index [3, 4, 0] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [35] build with the feature index [0, 6, 7] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [37] build with the feature index [8, 0, 2] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [36] build with the feature index [7, 1, 4] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [38] build with the feature index [8, 1, 7] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [39] build with the feature index [3, 6, 8] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [40] build with the feature index [1, 3, 4] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [41] build with the feature index [8, 3, 4] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [42] build with the feature index [4, 5, 6] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [43] build with the feature index [6, 5, 3] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [44] build with the feature index [7, 8, 0] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [45] build with the feature index [2, 0, 3] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [46] build with the feature index [4, 2, 7] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [47] build with the feature index [7, 0, 3] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [48] build with the feature index [2, 5, 1] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [49] build with the feature index [3, 8, 6] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [50] build with the feature index [8, 0, 3] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [51] build with the feature index [3, 2, 7] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [52] build with the feature index [8, 5, 2] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [53] build with the feature index [2, 4, 5] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [54] build with the feature index [8, 3, 5] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [55] build with the feature index [0, 1, 7] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [56] build with the feature index [0, 1, 8] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [57] build with the feature index [7, 3, 2] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [58] build with the feature index [5, 8, 0] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [59] build with the feature index [1, 3, 2] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [60] build with the feature index [0, 8, 3] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [61] build with the feature index [4, 3, 7] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [62] build with the feature index [4, 3, 5] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [63] build with the feature index [8, 1, 0] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [64] build with the feature index [3, 4, 8] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [65] build with the feature index [2, 1, 0] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [66] build with the feature index [2, 3, 8] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [67] build with the feature index [0, 7, 1] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [68] build with the feature index [1, 2, 3] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [69] build with the feature index [2, 8, 4] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [70] build with the feature index [1, 6, 3] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [71] build with the feature index [8, 5, 2] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [72] build with the feature index [8, 2, 7] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [73] build with the feature index [7, 6, 1] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [74] build with the feature index [8, 2, 7] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [75] build with the feature index [7, 2, 4] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [76] build with the feature index [4, 6, 7] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [77] build with the feature index [6, 7, 1] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [78] build with the feature index [3, 2, 5] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [79] build with the feature index [2, 3, 8] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [80] build with the feature index [4, 6, 1] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [81] build with the feature index [5, 4, 6] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [82] build with the feature index [4, 5, 2] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [83] build with the feature index [8, 0, 3] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [84] build with the feature index [8, 1, 2] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [85] build with the feature index [2, 8, 5] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [86] build with the feature index [0, 6, 1] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [87] build with the feature index [2, 3, 4] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [88] build with the feature index [4, 0, 8] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [89] build with the feature index [5, 1, 3] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [90] build with the feature index [3, 6, 8] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [91] build with the feature index [0, 8, 4] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [92] build with the feature index [5, 3, 6] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [93] build with the feature index [7, 4, 3] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [94] build with the feature index [4, 0, 8] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [95] build with the feature index [4, 2, 0] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [96] build with the feature index [8, 4, 5] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [97] build with the feature index [7, 4, 0] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [98] build with the feature index [3, 6, 5] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [99] build with the feature index [3, 0, 2] and data index [230065 250494  37253 ... 274949 143113  23736]
# Acc with oblique tree 0.6332371428571428

# %%
from TorshaMajumder.Decision_trees.RandCART import *
from TorshaMajumder.Decision_trees.segmentor import Twoing, MSE, MeanSegmentor
from TorshaMajumder.Decision_trees.split_criteria import gini, twoing

# Randomized CART
# 

cfg_base_estimator = {'impurity':MSE(),
                      'segmentor':MeanSegmentor(),
                      'max_depth':3,
                      'min_samples_split':2,
                      'compare_with_cart':False}

rf = RFClassifier(base_estimator=Rand_CART,
                  n_estimators=100,
                  params_estimators=cfg_base_estimator,
                  enable_logger=True)

rf._setup_logger(log_file='/content/drive/MyDrive/Testes e Experimentos/Testes/rf.rc.debuging.log')

rf = rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)

print('Acc with oblique tree', accuracy_score(y_test, y_pred))
# Out:
# INFO:rflog:Tree index [0] build with the feature index [5, 8, 0] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [1] build with the feature index [3, 0, 8] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [2] build with the feature index [4, 3, 0] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [3] build with the feature index [2, 1, 7] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [5] build with the feature index [1, 2, 0] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [4] build with the feature index [3, 2, 5] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [6] build with the feature index [3, 5, 4] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [7] build with the feature index [5, 4, 8] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [8] build with the feature index [3, 2, 5] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [9] build with the feature index [4, 8, 2] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [10] build with the feature index [5, 7, 6] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [11] build with the feature index [2, 6, 8] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [12] build with the feature index [7, 0, 2] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [13] build with the feature index [0, 6, 1] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [14] build with the feature index [1, 3, 4] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [15] build with the feature index [3, 1, 5] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [16] build with the feature index [8, 1, 5] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [17] build with the feature index [5, 6, 1] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [18] build with the feature index [3, 0, 7] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [19] build with the feature index [2, 7, 0] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [20] build with the feature index [7, 4, 8] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [21] build with the feature index [3, 6, 1] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [22] build with the feature index [4, 7, 1] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [23] build with the feature index [3, 1, 6] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [24] build with the feature index [0, 4, 2] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [25] build with the feature index [6, 5, 3] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [26] build with the feature index [3, 1, 4] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [27] build with the feature index [2, 7, 5] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [28] build with the feature index [0, 3, 2] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [29] build with the feature index [5, 2, 3] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [30] build with the feature index [3, 4, 2] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [31] build with the feature index [4, 6, 7] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [32] build with the feature index [3, 5, 0] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [33] build with the feature index [0, 3, 7] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [34] build with the feature index [3, 0, 5] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [35] build with the feature index [0, 5, 3] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [36] build with the feature index [8, 6, 0] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [37] build with the feature index [8, 5, 7] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [38] build with the feature index [3, 1, 5] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [39] build with the feature index [2, 4, 1] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [40] build with the feature index [4, 5, 8] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [41] build with the feature index [3, 4, 6] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [42] build with the feature index [3, 8, 5] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [43] build with the feature index [3, 4, 1] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [44] build with the feature index [0, 4, 8] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [45] build with the feature index [7, 2, 1] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [46] build with the feature index [1, 5, 4] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [47] build with the feature index [3, 4, 1] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [48] build with the feature index [4, 6, 8] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [49] build with the feature index [7, 5, 3] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [50] build with the feature index [4, 7, 2] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [51] build with the feature index [3, 6, 0] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [52] build with the feature index [6, 2, 5] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [53] build with the feature index [1, 5, 8] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [54] build with the feature index [6, 8, 3] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [55] build with the feature index [1, 2, 5] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [56] build with the feature index [3, 7, 0] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [57] build with the feature index [0, 1, 3] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [58] build with the feature index [8, 1, 3] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [59] build with the feature index [6, 0, 5] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [60] build with the feature index [0, 1, 6] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [61] build with the feature index [6, 7, 2] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [62] build with the feature index [0, 3, 8] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [63] build with the feature index [7, 6, 5] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [64] build with the feature index [1, 6, 0] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [65] build with the feature index [8, 6, 3] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [66] build with the feature index [0, 7, 1] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [67] build with the feature index [4, 2, 0] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [68] build with the feature index [0, 7, 3] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [69] build with the feature index [4, 0, 5] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [70] build with the feature index [6, 0, 7] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [71] build with the feature index [3, 4, 1] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [72] build with the feature index [4, 5, 3] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [73] build with the feature index [6, 7, 8] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [74] build with the feature index [0, 6, 8] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [75] build with the feature index [3, 7, 4] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [76] build with the feature index [8, 0, 1] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [77] build with the feature index [2, 8, 5] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [78] build with the feature index [4, 1, 3] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [79] build with the feature index [7, 2, 5] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [80] build with the feature index [7, 6, 1] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [81] build with the feature index [4, 3, 1] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [82] build with the feature index [3, 1, 7] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [83] build with the feature index [3, 1, 2] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [84] build with the feature index [7, 8, 4] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [85] build with the feature index [4, 2, 5] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [86] build with the feature index [3, 7, 6] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [87] build with the feature index [6, 5, 3] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [89] build with the feature index [2, 4, 3] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [88] build with the feature index [8, 0, 5] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [90] build with the feature index [0, 1, 7] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [91] build with the feature index [2, 3, 1] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [93] build with the feature index [1, 5, 6] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [92] build with the feature index [8, 1, 7] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [94] build with the feature index [1, 6, 5] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [95] build with the feature index [8, 2, 3] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [96] build with the feature index [0, 6, 3] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [97] build with the feature index [4, 3, 8] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [98] build with the feature index [3, 7, 4] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [99] build with the feature index [5, 1, 7] and data index [230065 250494  37253 ... 274949 143113  23736]
# Acc with oblique tree 0.6073142857142857

# %%
from TorshaMajumder.Decision_trees.WODT import *
from TorshaMajumder.Decision_trees.segmentor import Twoing, MSE, MeanSegmentor
from TorshaMajumder.Decision_trees.split_criteria import gini, twoing

# Weighted Oblique Decision Trees by [Bin-Bin Yang et al.]
#

cfg_base_estimator = {'max_depth':3,
                      'min_samples_split':2,
                      'max_features':'all'}

rf = RFClassifier(base_estimator=WeightedObliqueDecisionTreeClassifier,
                  n_estimators=100,
                  params_estimators=cfg_base_estimator,
                  enable_logger=True)

rf._setup_logger(log_file='/content/drive/MyDrive/Testes e Experimentos/Testes/rf.wodt.debuging.log')

rf = rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)

print('Acc with oblique tree', accuracy_score(y_test, y_pred))
# Out:
# INFO:rflog:Tree index [1] build with the feature index [2, 8, 7] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [2] build with the feature index [3, 1, 0] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [0] build with the feature index [2, 7, 4] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [4] build with the feature index [5, 6, 7] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [5] build with the feature index [4, 5, 0] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [6] build with the feature index [5, 0, 6] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [3] build with the feature index [3, 8, 0] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [7] build with the feature index [0, 5, 4] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [9] build with the feature index [2, 1, 6] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [8] build with the feature index [4, 8, 3] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [11] build with the feature index [6, 8, 7] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [10] build with the feature index [1, 5, 2] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [13] build with the feature index [6, 7, 1] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [12] build with the feature index [4, 5, 2] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [14] build with the feature index [6, 1, 4] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [15] build with the feature index [8, 7, 0] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [17] build with the feature index [2, 7, 3] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [16] build with the feature index [4, 2, 1] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [18] build with the feature index [4, 5, 2] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [19] build with the feature index [1, 8, 5] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [21] build with the feature index [7, 5, 0] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [20] build with the feature index [8, 1, 3] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [22] build with the feature index [1, 3, 4] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [23] build with the feature index [2, 7, 8] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [24] build with the feature index [4, 6, 8] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [25] build with the feature index [4, 8, 2] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [26] build with the feature index [3, 7, 8] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [28] build with the feature index [6, 3, 4] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [29] build with the feature index [4, 6, 7] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [27] build with the feature index [7, 4, 3] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [31] build with the feature index [6, 8, 1] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [30] build with the feature index [2, 7, 8] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [32] build with the feature index [1, 7, 5] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [34] build with the feature index [0, 1, 3] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [33] build with the feature index [3, 7, 1] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [35] build with the feature index [6, 5, 3] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [36] build with the feature index [2, 5, 0] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [37] build with the feature index [1, 4, 2] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [39] build with the feature index [8, 6, 4] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [38] build with the feature index [7, 5, 1] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [41] build with the feature index [3, 6, 5] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [42] build with the feature index [7, 0, 5] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [43] build with the feature index [7, 5, 6] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [40] build with the feature index [4, 3, 7] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [45] build with the feature index [3, 2, 8] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [44] build with the feature index [4, 8, 7] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [46] build with the feature index [5, 1, 0] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [47] build with the feature index [1, 8, 4] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [48] build with the feature index [6, 3, 1] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [49] build with the feature index [6, 0, 4] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [50] build with the feature index [8, 5, 4] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [51] build with the feature index [2, 8, 5] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [52] build with the feature index [7, 8, 5] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [53] build with the feature index [8, 5, 4] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [54] build with the feature index [1, 7, 8] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [55] build with the feature index [1, 7, 4] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [57] build with the feature index [5, 6, 7] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [58] build with the feature index [6, 5, 0] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [56] build with the feature index [8, 6, 4] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [60] build with the feature index [2, 6, 8] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [61] build with the feature index [1, 6, 0] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [59] build with the feature index [1, 4, 2] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [63] build with the feature index [2, 7, 0] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [62] build with the feature index [1, 4, 5] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [65] build with the feature index [7, 6, 4] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [64] build with the feature index [8, 4, 2] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [67] build with the feature index [7, 6, 4] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [68] build with the feature index [5, 6, 3] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [69] build with the feature index [1, 6, 7] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [70] build with the feature index [8, 5, 6] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [66] build with the feature index [7, 8, 4] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [72] build with the feature index [7, 4, 5] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [71] build with the feature index [1, 7, 2] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [73] build with the feature index [6, 2, 5] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [75] build with the feature index [6, 2, 7] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [74] build with the feature index [4, 3, 1] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [76] build with the feature index [4, 2, 5] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [78] build with the feature index [6, 7, 1] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [79] build with the feature index [6, 2, 5] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [77] build with the feature index [7, 2, 1] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [81] build with the feature index [5, 3, 4] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [80] build with the feature index [2, 3, 1] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [82] build with the feature index [1, 7, 5] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [84] build with the feature index [6, 3, 4] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [83] build with the feature index [6, 1, 0] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [86] build with the feature index [4, 3, 8] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [87] build with the feature index [2, 0, 7] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [85] build with the feature index [6, 8, 1] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [89] build with the feature index [4, 6, 1] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [90] build with the feature index [0, 2, 1] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [88] build with the feature index [1, 5, 8] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [91] build with the feature index [2, 6, 8] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [93] build with the feature index [1, 0, 5] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [92] build with the feature index [2, 5, 8] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [94] build with the feature index [4, 8, 1] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [95] build with the feature index [5, 0, 1] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [97] build with the feature index [0, 2, 7] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [96] build with the feature index [3, 1, 5] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [99] build with the feature index [2, 0, 3] and data index [230065 250494  37253 ... 274949 143113  23736]
#
# INFO:rflog:Tree index [98] build with the feature index [8, 3, 1] and data index [230065 250494  37253 ... 274949 143113  23736]
# Acc with oblique tree 0.5279442857142858
