# %% [markdown]
# # **Test RF with Mondrian Tree Classifier**

# %% [markdown]
# https://github.com/balajiln/mondrianforest/tree/
#
# https://scikit-garden.github.io/

# %%
# !pip install setuptools numpy scipy scikit-learn cython

# %%
# !pip install scikit-garden

# %%
FOLDERS= ['/content/drive/MyDrive/',
          '/content/drive/MyDrive/midas',
          '/content/drive/MyDrive/Testes e Experimentos/Testes/lib.external',
          '/content/drive/MyDrive/Testes e Experimentos/Testes/lib.external/MechCoder',
          '/content/drive/MyDrive/Testes e Experimentos/Testes/lib.external/MechCoder/skgarden'
        ]
import sys
for f in FOLDERS:
  sys.path.append(f)

import pandas as pd

import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.tree import DecisionTreeClassifier

from midas.v4.ensemble import RFClassifier

# %%
df_stream = pd.read_csv('https://github.com/scikit-multiflow/streaming-datasets/raw/master/agr_a.csv',
                        engine='c', low_memory=True, memory_map=True)

X = df_stream[df_stream.columns[:-1]]
y = df_stream['class']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.70, random_state=100)

# %% [markdown]
# ## Testa as árvores individualmente

# %%
from skgarden import MondrianForestRegressor
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-6ec51c88bd39> in <module>
# ----> 1 from skgarden import MondrianForestRegressor
#
# /usr/local/lib/python3.8/dist-packages/skgarden/__init__.py in <module>
#       1 from .forest import RandomForestRegressor
#       2 from .forest import ExtraTreesRegressor
# ----> 3 from .mondrian import MondrianForestClassifier
#       4 from .mondrian import MondrianForestRegressor
#       5 from .mondrian import MondrianTreeClassifier
#
# /usr/local/lib/python3.8/dist-packages/skgarden/mondrian/__init__.py in <module>
# ----> 1 from .ensemble import MondrianForestClassifier
#       2 from .ensemble import MondrianForestRegressor
#       3 from .tree import MondrianTreeClassifier
#       4 from .tree import MondrianTreeRegressor
#       5
#
# /usr/local/lib/python3.8/dist-packages/skgarden/mondrian/ensemble/__init__.py in <module>
# ----> 1 from .forest import MondrianForestClassifier
#       2 from .forest import MondrianForestRegressor
#       3
#       4 __all__ = ["MondrianTreeClassifier", "MondrianForestRegressor"]
#
# /usr/local/lib/python3.8/dist-packages/skgarden/mondrian/ensemble/forest.py in <module>
#       1 import numpy as np
#       2 from scipy import sparse
# ----> 3 from sklearn.ensemble.forest import ForestClassifier
#       4 from sklearn.ensemble.forest import ForestRegressor
#       5 from sklearn.exceptions import NotFittedError
#
# ModuleNotFoundError: No module named 'sklearn.ensemble.forest'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from skgarden import MondrianTreeClassifier

mtc = MondrianTreeClassifier(max_depth=3,
                             min_samples_split=2,
                             random_state=100)

mtc = mtc.fit(X_train, y_train)

y_pred = mtc.predict(X_test)

print('Acc with oblique tree', accuracy_score(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-b55f53037bc7> in <module>
# ----> 1 from skgarden import MondrianTreeClassifier
#       2
#       3 mtc = MondrianTreeClassifier(max_depth=3,
#       4                              min_samples_split=2,
#       5                              random_state=100)
#
# /usr/local/lib/python3.8/dist-packages/skgarden/__init__.py in <module>
#       1 from .forest import RandomForestRegressor
#       2 from .forest import ExtraTreesRegressor
# ----> 3 from .mondrian import MondrianForestClassifier
#       4 from .mondrian import MondrianForestRegressor
#       5 from .mondrian import MondrianTreeClassifier
#
# /usr/local/lib/python3.8/dist-packages/skgarden/mondrian/__init__.py in <module>
# ----> 1 from .ensemble import MondrianForestClassifier
#       2 from .ensemble import MondrianForestRegressor
#       3 from .tree import MondrianTreeClassifier
#       4 from .tree import MondrianTreeRegressor
#       5
#
# /usr/local/lib/python3.8/dist-packages/skgarden/mondrian/ensemble/__init__.py in <module>
# ----> 1 from .forest import MondrianForestClassifier
#       2 from .forest import MondrianForestRegressor
#       3
#       4 __all__ = ["MondrianTreeClassifier", "MondrianForestRegressor"]
#
# /usr/local/lib/python3.8/dist-packages/skgarden/mondrian/ensemble/forest.py in <module>
#       1 import numpy as np
#       2 from scipy import sparse
# ----> 3 from sklearn.ensemble.forest import ForestClassifier
#       4 from sklearn.ensemble.forest import ForestRegressor
#       5 from sklearn.exceptions import NotFittedError
#
# ModuleNotFoundError: No module named 'sklearn.ensemble.forest'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from stree import Stree

cfg_base_estimator = {'random_state':100,
                      'C':.01,
                      'max_iter':1e5,
                      'kernel':"liblinear",
                      'multiclass_strategy':"ovr"}

rf = RFClassifier(base_estimator=Stree,
                  n_estimators=10,
                  params_estimators=cfg_base_estimator,
                  enable_logger=True)

rf._setup_logger(log_file='/content/drive/MyDrive/Testes e Experimentos/Testes/rf.stree.debuging.log')

rf = rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)
